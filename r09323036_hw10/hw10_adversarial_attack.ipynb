# %% [markdown]
# # **Homework 10 - Adversarial Attack**
#
# Slides: https://reurl.cc/v5kXkk
#
# Video(En): https://youtu.be/313TZsUDQ48
#
# Video(Zh): https://youtu.be/xWHpPEvkDiE
#
# TA: ntu-ml-2021spring-ta@googlegroups.com

# %% [markdown]
# ## Enviroment & Download
#
# We make use of [pytorchcv](https://pypi.org/project/pytorchcv/) to obtain CIFAR-10 pretrained model, so we need to set up the enviroment first. We also need to download the data (200 images) which we want to attack.

# %%
import torch

torch.cuda.get_device_name()
# Out:
# 'Tesla V100-SXM2-16GB'

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ps -aux|grep python
# Out:
# root          60  0.0  0.2 198780 65672 ?        Sl   04:34   0:09 /usr/bin/python2 /usr/local/bin/jupyter-notebook --ip="172.28.0.2" --port=9000 --FileContentsManager.root_dir="/" --LargeFileManager.delete_to_trash=False --MappingKernelManager.root_dir="/content"
# root          95  0.1  0.0      0     0 ?        Z    04:36   0:13 [python3] <defunct>
# root         256  0.0  0.0  18384  2892 ?        S    04:36   0:00 bash -c tail -n +0 -F "/root/.config/Google/DriveFS/Logs/drive_fs.txt" | python3 /opt/google/drive/drive-filter.py > "/root/.config/Google/DriveFS/Logs/timeouts.txt"
# root         258  0.0  0.0  31744  9668 ?        S    04:36   0:00 python3 /opt/google/drive/drive-filter.py
# root        1003  3.2 11.9 26106464 3182472 ?    Ssl  05:51   3:14 /usr/bin/python3 -m ipykernel_launcher -f /root/.local/share/jupyter/runtime/kernel-928861c2-d21b-4d9e-9c10-8512a350bbb4.json
# root        1023  0.2  0.0 128416 16160 ?        Sl   05:51   0:17 /usr/bin/python3 /usr/local/lib/python3.7/dist-packages/debugpy/adapter --for-server 42053 --host 127.0.0.1 --port 17750 --server-access-token 38b1da74ba482a11e1ade0ca87e1dcbdb96fd01485e0aa95d3b60349e0e397df
# root        1469  0.0  0.0  39200  6600 ?        S    07:32   0:00 /bin/bash -c ps -aux|grep python
# root        1471  0.0  0.0  38580  5552 ?        S    07:32   0:00 grep python

# %%
# !kill -9 1003

# %%
# set up environment
# !pip install pytorchcv

# download
# !gdown --id 1fHi1ko7wr80wXkXpqpqpOxuYH1mClXoX -O data.zip

# unzip
# !unzip ./data.zip
# !rm ./data.zip
# Out:
# Requirement already satisfied: pytorchcv in /usr/local/lib/python3.7/dist-packages (0.0.65)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from pytorchcv) (2.23.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from pytorchcv) (1.19.5)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->pytorchcv) (2020.12.5)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->pytorchcv) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->pytorchcv) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->pytorchcv) (1.24.3)
# Downloading...
# From: https://drive.google.com/uc?id=1fHi1ko7wr80wXkXpqpqpOxuYH1mClXoX
# To: /data.zip
# 100% 490k/490k [00:00<00:00, 65.7MB/s]
# Archive:  ./data.zip
#    creating: data/
#    creating: data/deer/
#  extracting: data/deer/deer13.png
#  extracting: data/deer/deer6.png
#  extracting: data/deer/deer11.png
#  extracting: data/deer/deer2.png
#  extracting: data/deer/deer10.png
#  extracting: data/deer/deer16.png
#  extracting: data/deer/deer9.png
#  extracting: data/deer/deer20.png
#  extracting: data/deer/deer15.png
#  extracting: data/deer/deer19.png
#  extracting: data/deer/deer5.png
#  extracting: data/deer/deer14.png
#  extracting: data/deer/deer4.png
#  extracting: data/deer/deer8.png
#  extracting: data/deer/deer12.png
#  extracting: data/deer/deer1.png
#  extracting: data/deer/deer7.png
#  extracting: data/deer/deer17.png
#  extracting: data/deer/deer18.png
#  extracting: data/deer/deer3.png
#    creating: data/horse/
#  extracting: data/horse/horse9.png
#  extracting: data/horse/horse1.png
#  extracting: data/horse/horse16.png
#  extracting: data/horse/horse15.png
#  extracting: data/horse/horse19.png
#  extracting: data/horse/horse14.png
#  extracting: data/horse/horse10.png
#  extracting: data/horse/horse7.png
#  extracting: data/horse/horse2.png
#  extracting: data/horse/horse6.png
#  extracting: data/horse/horse20.png
#  extracting: data/horse/horse5.png
#  extracting: data/horse/horse18.png
#  extracting: data/horse/horse12.png
#  extracting: data/horse/horse13.png
#  extracting: data/horse/horse17.png
#  extracting: data/horse/horse4.png
#  extracting: data/horse/horse11.png
#  extracting: data/horse/horse8.png
#  extracting: data/horse/horse3.png
#    creating: data/ship/
#  extracting: data/ship/ship10.png
#  extracting: data/ship/ship14.png
#  extracting: data/ship/ship9.png
#  extracting: data/ship/ship20.png
#  extracting: data/ship/ship5.png
#  extracting: data/ship/ship8.png
#  extracting: data/ship/ship19.png
#  extracting: data/ship/ship16.png
#  extracting: data/ship/ship13.png
#  extracting: data/ship/ship6.png
#  extracting: data/ship/ship17.png
#  extracting: data/ship/ship1.png
#  extracting: data/ship/ship12.png
#  extracting: data/ship/ship2.png
#  extracting: data/ship/ship3.png
#  extracting: data/ship/ship15.png
#  extracting: data/ship/ship4.png
#  extracting: data/ship/ship7.png
#  extracting: data/ship/ship11.png
#  extracting: data/ship/ship18.png
#    creating: data/frog/
#  extracting: data/frog/frog10.png
#  extracting: data/frog/frog4.png
#  extracting: data/frog/frog5.png
#  extracting: data/frog/frog20.png
#  extracting: data/frog/frog15.png
#  extracting: data/frog/frog3.png
#  extracting: data/frog/frog1.png
#  extracting: data/frog/frog14.png
#  extracting: data/frog/frog2.png
#  extracting: data/frog/frog19.png
#  extracting: data/frog/frog7.png
#  extracting: data/frog/frog11.png
#  extracting: data/frog/frog17.png
#  extracting: data/frog/frog18.png
#  extracting: data/frog/frog12.png
#  extracting: data/frog/frog16.png
#  extracting: data/frog/frog8.png
#  extracting: data/frog/frog13.png
#  extracting: data/frog/frog6.png
#  extracting: data/frog/frog9.png
#    creating: data/airplane/
#  extracting: data/airplane/airplane3.png
#  extracting: data/airplane/airplane4.png
#  extracting: data/airplane/airplane2.png
#  extracting: data/airplane/airplane9.png
#  extracting: data/airplane/airplane20.png
#  extracting: data/airplane/airplane18.png
#  extracting: data/airplane/airplane19.png
#  extracting: data/airplane/airplane10.png
#  extracting: data/airplane/airplane6.png
#  extracting: data/airplane/airplane13.png
#  extracting: data/airplane/airplane16.png
#  extracting: data/airplane/airplane14.png
#  extracting: data/airplane/airplane11.png
#  extracting: data/airplane/airplane1.png
#  extracting: data/airplane/airplane17.png
#  extracting: data/airplane/airplane7.png
#  extracting: data/airplane/airplane15.png
#  extracting: data/airplane/airplane5.png
#  extracting: data/airplane/airplane8.png
#  extracting: data/airplane/airplane12.png
#    creating: data/bird/
#  extracting: data/bird/bird9.png
#  extracting: data/bird/bird12.png
#  extracting: data/bird/bird10.png
#  extracting: data/bird/bird11.png
#  extracting: data/bird/bird5.png
#  extracting: data/bird/bird8.png
#  extracting: data/bird/bird4.png
#  extracting: data/bird/bird3.png
#  extracting: data/bird/bird7.png
#  extracting: data/bird/bird18.png
#  extracting: data/bird/bird14.png
#  extracting: data/bird/bird13.png
#  extracting: data/bird/bird2.png
#  extracting: data/bird/bird15.png
#  extracting: data/bird/bird17.png
#  extracting: data/bird/bird19.png
#  extracting: data/bird/bird16.png
#  extracting: data/bird/bird6.png
#  extracting: data/bird/bird20.png
#  extracting: data/bird/bird1.png
#    creating: data/cat/
#  extracting: data/cat/cat6.png
#  extracting: data/cat/cat1.png
#  extracting: data/cat/cat7.png
#  extracting: data/cat/cat19.png
#  extracting: data/cat/cat5.png
#  extracting: data/cat/cat9.png
#  extracting: data/cat/cat17.png
#  extracting: data/cat/cat2.png
#  extracting: data/cat/cat16.png
#  extracting: data/cat/cat10.png
#  extracting: data/cat/cat4.png
#  extracting: data/cat/cat18.png
#  extracting: data/cat/cat13.png
#  extracting: data/cat/cat11.png
#  extracting: data/cat/cat20.png
#  extracting: data/cat/cat15.png
#  extracting: data/cat/cat8.png
#  extracting: data/cat/cat14.png
#  extracting: data/cat/cat3.png
#  extracting: data/cat/cat12.png
#    creating: data/automobile/
#  extracting: data/automobile/automobile17.png
#  extracting: data/automobile/automobile11.png
#  extracting: data/automobile/automobile5.png
#  extracting: data/automobile/automobile10.png
#  extracting: data/automobile/automobile20.png
#  extracting: data/automobile/automobile2.png
#  extracting: data/automobile/automobile6.png
#  extracting: data/automobile/automobile1.png
#  extracting: data/automobile/automobile19.png
#  extracting: data/automobile/automobile7.png
#  extracting: data/automobile/automobile16.png
#  extracting: data/automobile/automobile3.png
#  extracting: data/automobile/automobile14.png
#  extracting: data/automobile/automobile12.png
#  extracting: data/automobile/automobile9.png
#  extracting: data/automobile/automobile4.png
#  extracting: data/automobile/automobile8.png
#  extracting: data/automobile/automobile13.png
#  extracting: data/automobile/automobile18.png
#  extracting: data/automobile/automobile15.png
#    creating: data/dog/
#  extracting: data/dog/dog9.png
#  extracting: data/dog/dog2.png
#  extracting: data/dog/dog15.png
#  extracting: data/dog/dog8.png
#  extracting: data/dog/dog3.png
#  extracting: data/dog/dog19.png
#  extracting: data/dog/dog12.png
#  extracting: data/dog/dog7.png
#  extracting: data/dog/dog17.png
#  extracting: data/dog/dog11.png
#  extracting: data/dog/dog16.png
#  extracting: data/dog/dog20.png
#  extracting: data/dog/dog4.png
#  extracting: data/dog/dog5.png
#  extracting: data/dog/dog14.png
#  extracting: data/dog/dog18.png
#  extracting: data/dog/dog10.png
#  extracting: data/dog/dog1.png
#  extracting: data/dog/dog13.png
#  extracting: data/dog/dog6.png
#    creating: data/truck/
#  extracting: data/truck/truck1.png
#  extracting: data/truck/truck18.png
#  extracting: data/truck/truck9.png
#  extracting: data/truck/truck4.png
#  extracting: data/truck/truck14.png
#  extracting: data/truck/truck8.png
#  extracting: data/truck/truck12.png
#  extracting: data/truck/truck15.png
#  extracting: data/truck/truck2.png
#  extracting: data/truck/truck5.png
#  extracting: data/truck/truck3.png
#  extracting: data/truck/truck10.png
#  extracting: data/truck/truck17.png
#  extracting: data/truck/truck20.png
#  extracting: data/truck/truck19.png
#  extracting: data/truck/truck13.png
#  extracting: data/truck/truck7.png
#  extracting: data/truck/truck6.png
#   inflating: data/truck/truck16.png
#  extracting: data/truck/truck11.png

# %% [markdown]
# ## Global Settings
#
# * $\epsilon$ is fixed to be 8. But on **Data section**, we will first apply transforms on raw pixel value (0-255 scale) **by ToTensor (to 0-1 scale)** and then **Normalize (subtract mean divide std)**. $\epsilon$ should be set to $\frac{8}{255 * std}$ during attack.
#
# * Explaination (optional)
#     * Denote the first pixel of original image as $p$, and the first pixel of adversarial image as $a$.
#     * The $\epsilon$ constraints tell us $\left| p-a \right| <= 8$.
#     * ToTensor() can be seen as a function where $T(x) = x/255$.
#     * Normalize() can be seen as a function where $N(x) = (x-mean)/std$ where $mean$ and $std$ are constants.
#     * After applying ToTensor() and Normalize() on $p$ and $a$, the constraint becomes $\left| N(T(p))-N(T(a)) \right| = \left| \frac{\frac{p}{255}-mean}{std}-\frac{\frac{a}{255}-mean}{std} \right| = \frac{1}{255 * std} \left| p-a \right| <= \frac{8}{255 * std}.$
#     * So, we should set $\epsilon$ to be $\frac{8}{255 * std}$ after ToTensor() and Normalize().

# %%
import torch
import torch.nn as nn

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(device)
batch_size = 8

# the mean and std are the calculated statistics from cifar_10 dataset
cifar_10_mean = (0.491, 0.482, 0.447) # mean for the three channels of cifar_10 images
cifar_10_std = (0.202, 0.199, 0.201) # std for the three channels of cifar_10 images

# convert mean and std to 3-dimensional tensors for future operations
mean = torch.tensor(cifar_10_mean).to(device).view(3, 1, 1)
std = torch.tensor(cifar_10_std).to(device).view(3, 1, 1)

epsilon = 8/255/std
# TODO: iterative fgsm attack
# alpha (step size) can be decided by yourself
alpha = 0.8/255/std + 0.03
print(alpha)
root = './data' # directory for storing benign images
# benign images: images which do not contain adversarial perturbations
# adversarial images: images which include adversarial perturbations
# Out:
# cuda
# tensor([[[0.0455]],
#
#         [[0.0458]],
#
#         [[0.0456]]], device='cuda:0')

# %% [markdown]
# ## Data
#
# Construct dataset and dataloader from root directory. Note that we store the filename of each image for future usage.

# %%
import os
import glob
import shutil
import numpy as np
from PIL import Image
from torchvision.transforms import transforms
from torch.utils.data import Dataset, DataLoader

transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(cifar_10_mean, cifar_10_std)
])

class AdvDataset(Dataset):
    def __init__(self, data_dir, transform):
        self.images = []
        self.labels = []
        self.names = []
        '''
        data_dir
        ├── class_dir
        │   ├── class1.png
        │   ├── ...
        │   ├── class20.png
        '''
        for i, class_dir in enumerate(sorted(glob.glob(f'{data_dir}/*'))):
            images = sorted(glob.glob(f'{class_dir}/*'))
            self.images += images
            self.labels += ([i] * len(images))
            self.names += [os.path.relpath(imgs, data_dir) for imgs in images]
        self.transform = transform
    def __getitem__(self, idx):
        image = self.transform(Image.open(self.images[idx]))
        label = self.labels[idx]
        return image, label
    def __getname__(self):
        return self.names
    def __len__(self):
        return len(self.images)

adv_set = AdvDataset(root, transform=transform)
adv_names = adv_set.__getname__()
adv_loader = DataLoader(adv_set, batch_size=batch_size, shuffle=False)

print(f'number of images = {adv_set.__len__()}')
# Out:
# number of images = 200

# %% [markdown]
# ## Utils -- Benign Images Evaluation

# %%
# to evaluate the performance of model on benign images
def epoch_benign(model, loader, loss_fn):
    model.eval()
    train_acc, train_loss = 0.0, 0.0
    for x, y in loader:
        x, y = x.to(device), y.to(device)
        yp = model(x)
        loss = loss_fn(yp, y)
        train_acc += (yp.argmax(dim=1) == y).sum().item()
        train_loss += loss.item() * x.shape[0]
    return train_acc / len(loader.dataset), train_loss / len(loader.dataset)

# %% [markdown]
# ## Utils -- Attack Algorithm

# %%
# perform fgsm attack
def fgsm(model, x, y, loss_fn, epsilon=epsilon):
    x_adv = x.detach().clone() # initialize x_adv as original benign image x
    x_adv.requires_grad = True # need to obtain gradient of x_adv, thus set required grad
    
    # ave_log = 0
    # for i in model:
    #   log = i(x_adv)
    #   ave_log += log
    # ave_log = ave_log/len(model)
    # #ave_log = model(x_adv)
    # loss = loss_fn(ave_log, y) # calculate loss
    # print(loss)
    # loss.backward()

    
    ave_log = model(x_adv)
    loss = loss_fn(ave_log, y) # calculate loss
    print(loss)
    loss.backward() # calculate gradient
    
    # fgsm: use gradient ascent on x_adv to maximize loss
    x_adv = x_adv + epsilon * x_adv.grad.detach().sign() 
    # x_adv.grad.detach().sign() -> sign(∇xJ(x, y))
    return x_adv

# TODO: perform iterative fgsm attack
# set alpha as the step size in Global Settings section
# alpha and num_iter can be decided by yourself
def ifgsm(model, x, y, loss_fn, epsilon=epsilon, alpha=alpha, num_iter=20):
    # initialize x_adv as original benign image x
    x_adv = x.detach().clone()
    # write a loop of num_iter to represent the iterative times
    # for each loop
    for i in range(num_iter):
        # call fgsm with (epsilon = alpha) to obtain new x_adv
        x_adv = fgsm(model, x_adv, y, loss_fn, alpha)
        # clip new x_adv back to [x-epsilon, x+epsilon]
        x_adv = torch.max(torch.min(x_adv, x+epsilon), x-epsilon)
    return x_adv

g=0
mu=0.9
def mf(model, x, y, loss_fn, epsilon=epsilon, gg=g, m=mu):
    x_adv = x.detach().clone() # initialize x_adv as original benign image x
    x_adv.requires_grad = True # need to obtain gradient of x_adv, thus set required grad
    ave_log = 0

    for i in model:
      log = i(x_adv)
      ave_log += log
    #   loss = loss_fn(i(x_adv), y)
    #   ave_log += loss
    ave_log = ave_log/len(model)
    loss = loss_fn(ave_log, y)
    # ave_log = model(x_adv)
     # calculate loss
    print(loss)
    loss.backward() # calculate gradient
    # fgsm: use gradient ascent on x_adv to maximize loss
    gg = mu*gg + x_adv.grad.detach()
    x_adv = x_adv + epsilon * gg.sign()
    # x_adv.grad.detach().sign() -> sign(∇xJ(x, y))
    return x_adv

# https://arxiv.org/pdf/1710.06081.pdf

def mifgsm(model, x, y, loss_fn, epsilon=epsilon, alpha=alpha, num_iter=60):
    # initialize x_adv as original benign image x
    x_adv = x.detach().clone() # initialize x_adv as original benign image x
    # write a loop of num_iter to represent the iterative times
    # for each loop

    for i in range(num_iter):
        # x_adv = x.detach().clone()
        # x_adv.requires_grad = True # need to obtain gradient of x_adv, thus set required grad
        # loss = loss_fn(model(x_adv), y) # calculate loss
        # loss.backward()
        # g = mu*g + x_adv.grad.detach().sign()
        # x_adv = x_adv + alpha * g
        # alpha = 
        # i += 1
        x_adv = mf(model, x_adv, y, loss_fn, alpha)
        x_adv = torch.max(torch.min(x_adv, x+epsilon), x-epsilon)

    return x_adv

# %% [markdown]
# ## Utils -- Attack
#
# * Recall
#     * ToTensor() can be seen as a function where $T(x) = x/255$.
#     * Normalize() can be seen as a function where $N(x) = (x-mean)/std$ where $mean$ and $std$ are constants.
#
# * Inverse function
#     * Inverse Normalize() can be seen as a function where $N^{-1}(x) = x*std+mean$ where $mean$ and $std$ are constants.
#     * Inverse ToTensor() can be seen as a function where $T^{-1}(x) = x*255$.
#
# * Special Noted
#     * ToTensor() will also convert the image from shape (height, width, channel) to shape (channel, height, width), so we also need to transpose the shape back to original shape.
#     * Since our dataloader samples a batch of data, what we need here is to transpose **(batch_size, channel, height, width)** back to **(batch_size, height, width, channel)** using np.transpose.

# %%
# perform adversarial attack and generate adversarial examples
def gen_adv_examples_en(en, model, loader, attack, loss_fn):
    model.eval()
    adv_names = []
    train_acc, train_loss = 0.0, 0.0
    for i, (x, y) in enumerate(loader):
        x, y = x.to(device), y.to(device)
        x_adv = attack(en, x, y, loss_fn) # obtain adversarial examples
        yp = model(x_adv)
        loss = loss_fn(yp, y)
        train_acc += (yp.argmax(dim=1) == y).sum().item()
        train_loss += loss.item() * x.shape[0]
        # store adversarial examples
        adv_ex = ((x_adv) * std + mean).clamp(0, 1) # to 0-1 scale
        adv_ex = (adv_ex * 255).clamp(0, 255) # 0-255 scale
        adv_ex = adv_ex.detach().cpu().data.numpy().round() # round to remove decimal part
        adv_ex = adv_ex.transpose((0, 2, 3, 1)) # transpose (bs, C, H, W) back to (bs, H, W, C)
        adv_examples = adv_ex if i == 0 else np.r_[adv_examples, adv_ex]
    return adv_examples, train_acc / len(loader.dataset), train_loss / len(loader.dataset)

# create directory which stores adversarial examples
def create_dir(data_dir, adv_dir, adv_examples, adv_names):
    if os.path.exists(adv_dir) is not True:
        _ = shutil.copytree(data_dir, adv_dir)
    for example, name in zip(adv_examples, adv_names):
        im = Image.fromarray(example.astype(np.uint8)) # image pixel value should be unsigned int
        im.save(os.path.join(adv_dir, name))

# %%
# perform adversarial attack and generate adversarial examples
def gen_adv_examples(model, loader, attack, loss_fn):
    model.eval()
    adv_names = []
    train_acc, train_loss = 0.0, 0.0
    for i, (x, y) in enumerate(loader):
        x, y = x.to(device), y.to(device)
        x_adv = attack(model, x, y, loss_fn) # obtain adversarial examples
        yp = model(x_adv)
        loss = loss_fn(yp, y)
        train_acc += (yp.argmax(dim=1) == y).sum().item()
        train_loss += loss.item() * x.shape[0]
        # store adversarial examples
        adv_ex = ((x_adv) * std + mean).clamp(0, 1) # to 0-1 scale
        adv_ex = (adv_ex * 255).clamp(0, 255) # 0-255 scale
        adv_ex = adv_ex.detach().cpu().data.numpy().round() # round to remove decimal part
        adv_ex = adv_ex.transpose((0, 2, 3, 1)) # transpose (bs, C, H, W) back to (bs, H, W, C)
        adv_examples = adv_ex if i == 0 else np.r_[adv_examples, adv_ex]
    return adv_examples, train_acc / len(loader.dataset), train_loss / len(loader.dataset)

# create directory which stores adversarial examples
def create_dir(data_dir, adv_dir, adv_examples, adv_names):
    if os.path.exists(adv_dir) is not True:
        _ = shutil.copytree(data_dir, adv_dir)
    for example, name in zip(adv_examples, adv_names):
        im = Image.fromarray(example.astype(np.uint8))
        print(im) # image pixel value should be unsigned int
        im.save(os.path.join(adv_dir, name))

# %%
# perform adversarial attack and generate adversarial examples
def get_en_loss(model, loader, attack, loss_fn):
    model.eval()
    adv_names = []
    logits_en = []
    train_acc, train_loss = 0.0, 0.0
    for i, (x, y) in enumerate(loader):
        x, y = x.to(device), y.to(device)
        x_adv = attack(model, x, y, loss_fn) # obtain adversarial examples
        logits = model(x_adv)
        logits_en.append(logits)
    return logits_en

# %% [markdown]
# ## Model / Loss Function
#
# Model list is available [here](https://github.com/osmr/imgclsmob/blob/master/pytorch/pytorchcv/model_provider.py). Please select models which has _cifar10 suffix. Some of the models cannot be accessed/loaded. You can safely skip them since TA's model will not use those kinds of models.

# %%
enmodel = ['resnet20_cifar10']
len(enmodel)
# Out:
# 1

# %%
from pytorchcv.model_provider import get_model as ptcv_get_model
model = ptcv_get_model('resnet20_cifar10', pretrained=True).to(device).eval()
model1 = ptcv_get_model('resnet56_cifar10', pretrained=True).to(device).eval()
model2 = ptcv_get_model('resnet110_cifar10', pretrained=True).to(device).eval()
model3 = ptcv_get_model('resnet164bn_cifar10', pretrained=True).to(device).eval()
model4 = ptcv_get_model('resnet272bn_cifar10', pretrained=True).to(device).eval()
model5 = ptcv_get_model('resnet542bn_cifar10', pretrained=True).to(device).eval()
model6 = ptcv_get_model('resnet1001_cifar10', pretrained=True).to(device).eval()
model7 = ptcv_get_model('resnet1202_cifar10', pretrained=True).to(device).eval()
model8 = ptcv_get_model('preresnet20_cifar10', pretrained=True).to(device).eval()
model9 = ptcv_get_model('preresnet272bn_cifar10', pretrained=True).to(device).eval()
model10 = ptcv_get_model('preresnet1202_cifar10', pretrained=True).to(device).eval()
model11 = ptcv_get_model('preresnet542bn_cifar10', pretrained=True).to(device).eval()
# Out:
# Downloading /root/.torch/models/resnet20_cifar10-0597-9b0024ac.pth.zip from https://github.com/osmr/imgclsmob/releases/download/v0.0.163/resnet20_cifar10-0597-9b0024ac.pth.zip...
# Downloading /root/.torch/models/resnet56_cifar10-0452-628c42a2.pth.zip from https://github.com/osmr/imgclsmob/releases/download/v0.0.163/resnet56_cifar10-0452-628c42a2.pth.zip...
# Downloading /root/.torch/models/resnet110_cifar10-0369-4d6ca1fc.pth.zip from https://github.com/osmr/imgclsmob/releases/download/v0.0.163/resnet110_cifar10-0369-4d6ca1fc.pth.zip...
# Downloading /root/.torch/models/resnet164bn_cifar10-0368-74ae9f4b.pth.zip from https://github.com/osmr/imgclsmob/releases/download/v0.0.179/resnet164bn_cifar10-0368-74ae9f4b.pth.zip...
# Downloading /root/.torch/models/resnet272bn_cifar10-0333-84f28e0c.pth.zip from https://github.com/osmr/imgclsmob/releases/download/v0.0.368/resnet272bn_cifar10-0333-84f28e0c.pth.zip...
# Downloading /root/.torch/models/resnet542bn_cifar10-0343-0fd36dd1.pth.zip from https://github.com/osmr/imgclsmob/releases/download/v0.0.369/resnet542bn_cifar10-0343-0fd36dd1.pth.zip...
# Downloading /root/.torch/models/resnet1001_cifar10-0328-77a179e2.pth.zip from https://github.com/osmr/imgclsmob/releases/download/v0.0.201/resnet1001_cifar10-0328-77a179e2.pth.zip...
# Downloading /root/.torch/models/resnet1202_cifar10-0353-1d5a2129.pth.zip from https://github.com/osmr/imgclsmob/releases/download/v0.0.214/resnet1202_cifar10-0353-1d5a2129.pth.zip...
# Downloading /root/.torch/models/preresnet20_cifar10-0651-76cec68d.pth.zip from https://github.com/osmr/imgclsmob/releases/download/v0.0.164/preresnet20_cifar10-0651-76cec68d.pth.zip...
# Downloading /root/.torch/models/preresnet272bn_cifar10-0325-1a6a016e.pth.zip from https://github.com/osmr/imgclsmob/releases/download/v0.0.389/preresnet272bn_cifar10-0325-1a6a016e.pth.zip...
# Downloading /root/.torch/models/preresnet1202_cifar10-0339-6fc686b0.pth.zip from https://github.com/osmr/imgclsmob/releases/download/v0.0.246/preresnet1202_cifar10-0339-6fc686b0.pth.zip...
# Downloading /root/.torch/models/preresnet542bn_cifar10-0314-66fd6f20.pth.zip from https://github.com/osmr/imgclsmob/releases/download/v0.0.391/preresnet542bn_cifar10-0314-66fd6f20.pth.zip...

# %%
en = [model, model1, model2, model3, model4, model5, model6, model7, model8, model9, model10, model11]

# %%
from pytorchcv.model_provider import get_model as ptcv_get_model
model_x = ptcv_get_model('resnet20_cifar10', pretrained=True).to(device)
loss_fn = nn.CrossEntropyLoss()
adv_examples, acc, loss = gen_adv_examples_en(en, model_x, adv_loader, mifgsm, loss_fn)
print(f'fgsm_acc = {acc:.5f}, fgsm_loss = {loss:.5f}')
# Out:
# tensor(0.0505, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(1.8100, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(4.8448, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(6.3337, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(7.4751, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(8.3070, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(8.7892, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(9.5123, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(10.0581, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(10.4125, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(10.7887, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(11.3481, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(11.2709, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(11.7872, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(11.7945, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(12.2940, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(12.3402, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(12.6400, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(12.8467, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(12.9275, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(12.9530, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(13.3906, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(13.3991, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(13.7856, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(13.4537, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(13.9183, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(13.9668, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(14.1487, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(13.9003, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(14.3276, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(14.3470, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(14.4509, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(14.2865, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(14.7783, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(14.5871, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(14.6581, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(14.7372, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(14.9060, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(14.7418, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(14.9781, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(15.1178, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(15.0415, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(14.9409, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(15.2468, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(15.1192, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(15.3062, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(15.0797, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(15.5489, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(15.3188, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(15.6913, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(15.3281, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(15.6643, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(15.4488, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(15.4347, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(15.4375, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(15.9169, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(15.5398, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(15.8261, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(15.6283, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(16.0493, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.0065, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(1.2163, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(4.8254, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(6.7735, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(7.6540, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(8.3132, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(8.6690, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(9.3285, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(9.4035, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(9.7920, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(10.2315, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(10.8374, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(11.4509, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(12.0644, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(12.2279, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(12.4993, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(12.8804, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(13.0142, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(13.5182, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(13.2661, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(13.6307, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(13.4783, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(13.9150, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(13.9022, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(13.7375, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(13.9831, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(14.3050, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(14.3022, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(14.5040, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(14.3915, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(14.6921, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(14.6055, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(14.6524, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(14.5523, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(14.5274, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(14.7838, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(14.6819, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(14.9314, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(15.0671, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(14.9481, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(14.9362, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(15.0885, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(15.2979, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(15.2285, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(15.3118, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(15.2468, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(15.2536, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(15.4231, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(15.5145, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(15.4803, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(15.7032, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(15.4132, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(15.6008, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(15.6539, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(15.5027, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(15.6566, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(15.5844, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(15.7600, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(15.3175, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(15.7051, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.0175, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.8306, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(3.0864, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(5.4563, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(6.7542, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(7.6024, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(8.1432, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(8.4572, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(8.8551, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(9.5490, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(10.5451, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(10.8946, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(11.4387, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(11.4640, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(12.1189, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(12.0487, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(12.5885, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(12.6520, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(12.7904, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(12.9062, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(13.2118, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(13.3078, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(13.4794, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(13.4780, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(13.7822, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(13.7041, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(13.8039, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(13.7790, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(14.1517, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(14.1629, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(13.9002, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(14.0114, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(14.3598, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(14.2215, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(14.1197, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(14.
device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(12.8008, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(12.8576, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(12.9796, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(13.1423, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(13.0115, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(13.1318, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(13.2467, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(13.2508, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(13.1921, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(13.2625, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(13.3597, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(13.4340, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(13.4479, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(13.4964, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(13.5471, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(13.6108, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(13.5996, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(13.5570, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(13.7219, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(13.7108, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(13.8329, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(13.6806, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(13.8458, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(13.7417, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(13.9197, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(13.8957, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(14.0048, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(13.9607, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(13.9767, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(13.8280, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(14.0147, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(13.9307, device='cuda:0', grad_fn=<NllLossBackward>)
# fgsm_acc = 0.00000, fgsm_loss = 13.90965

# %%
create_dir(root, 'mifgsm', adv_examples, adv_names)

# %%
for example, name in zip(adv_examples, adv_names):
    im = Image.fromarray(example.astype(np.uint8))
    im.save(os.path.join('mifgsm', name))

# %%
from pytorchcv.model_provider import get_model as ptcv_get_model

model = ptcv_get_model('resnet20_cifar10', pretrained=True).to(device)
loss_fn = nn.CrossEntropyLoss()

benign_acc, benign_loss = epoch_benign(model, adv_loader, loss_fn)
print(f'benign_acc = {benign_acc:.5f}, benign_loss = {benign_loss:.5f}')
# Out:
# benign_acc = 0.94500, benign_loss = 0.17499

# %% [markdown]
# ## FGSM

# %%
from pytorchcv.model_provider import get_model as ptcv_get_model

model = ptcv_get_model('resnet20_cifar10', pretrained=True).to(device)
loss_fn = nn.CrossEntropyLoss()
adv_examples, fgsm_acc, fgsm_loss = gen_adv_examples(model, adv_loader, fgsm, loss_fn)
print(f'fgsm_acc = {fgsm_acc:.5f}, fgsm_loss = {fgsm_loss:.5f}')

create_dir(root, 'fgsm', adv_examples, adv_names)
# Out:
# tensor(0.0687, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.0134, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.0440, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.0083, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.4167, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.8183, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.0891, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.0335, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.0724, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.6943, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.0624, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.1116, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.4847, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.3297, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.0278, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.3480, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.0053, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.0083, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.0132, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.0319, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.0064, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.0974, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.0052, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.5506, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.0334, device='cuda:0', grad_fn=<NllLossBackward>)
# fgsm_acc = 0.32000, fgsm_loss = 3.44287

# %% [markdown]
# ## I-FGSM

# %%
# TODO: iterative fgsm attack

model_x = ptcv_get_model('resnet20_cifar10', pretrained=True).to(device)
adv_examples, ifgsm_acc, ifgsm_loss = gen_adv_examples_en(en[0], model_x,adv_loader, ifgsm, loss_fn)
print(f'ifgsm_acc = {ifgsm_acc:.5f}, ifgsm_loss = {ifgsm_loss:.5f}')

create_dir(root, 'ifgsm', adv_examples, adv_names)
# Out:
# tensor(0.0687, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(1.7194, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(4.5506, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(6.7381, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(8.5497, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(10.2791, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(11.5644, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(12.5144, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(13.2456, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(14.2239, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(14.6999, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(15.3606, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(15.9158, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(16.4164, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(16.4701, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(16.9543, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(17.3837, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(17.7011, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(17.9385, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(18.2466, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.0134, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(1.6261, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(5.4974, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(7.6807, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(9.0610, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(10.0512, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(11.0655, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(11.8450, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(12.8784, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(13.6767, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(14.3157, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(14.5867, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(15.1571, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(15.5236, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(16.0244, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(16.2204, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(16.6517, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(16.9095, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(17.2559, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(17.3330, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.0440, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(1.5035, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(4.0390, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(6.3175, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(8.2235, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(9.6212, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(10.9024, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(11.7153, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(12.6297, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(13.9583, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(14.6418, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(15.4095, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(15.8611, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(16.2792, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(16.5971, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(16.9774, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(17.2758, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(17.4512, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(17.6952, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(18.0519, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.0083, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.8861, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(2.7573, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(4.3398, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(5.7284, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(7.2282, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(9.1635, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(10.7608, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(12.1288, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(13.3092, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(14.3454, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(14.9783, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(15.6110, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(15.9600, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(16.5323, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(16.7953, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(17.0774, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(17.3466, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(17.5883, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(17.8599, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.4167, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(2.4263, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(4.1448, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(5.6332, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(7.1096, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(8.7584, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(10.2657, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(11.5079, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(12.6169, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(13.4860, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(14.1584, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(14.6474, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(15.1684, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(15.5910, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(15.9810, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(16.4393, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(16.6900, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(16.9808, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(17.1374, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(17.4373, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.8183, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(3.3714, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(5.3112, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(7.3013, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(9.2259, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(11.3739, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(13.0231, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(14.0442, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(14.9246, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(15.8437, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(16.4633, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(17.1548, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(17.7344, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(18.3741, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(18.6865, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(19.2014, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(19.6345, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(19.8807, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(20.1697, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(20.4803, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.0891, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(2.2712, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(5.2593, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(7.5486, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(9.1969, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(10.6800, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(11.5738, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(13.1296, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(13.
device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(6.7661, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(8.7414, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(10.4041, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(11.7605, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(12.5881, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(13.4193, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(14.0921, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(14.6574, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(15.0892, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(15.4063, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(15.7150, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(16.0592, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(16.3847, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(16.7061, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(16.9823, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.0334, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(0.6133, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(1.7046, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(4.8185, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(7.1438, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(8.6408, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(9.8201, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(10.6716, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(11.4192, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(12.2714, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(12.8905, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(13.4125, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(13.9465, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(14.5981, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(15.1044, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(15.7336, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(16.0908, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(16.5883, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(16.8654, device='cuda:0', grad_fn=<NllLossBackward>)
# tensor(17.0941, device='cuda:0', grad_fn=<NllLossBackward>)
# ifgsm_acc = 0.00000, ifgsm_loss = 19.86394

# %%
# Out:
# ifgsm_acc = 0.00000, ifgsm_loss = 20.60922

# %% [markdown]
# ## Compress the images

# %%
# %cd fgsm
# !tar zcvf ../fgsm.tgz *
# %cd ..

# %cd mifgsm
# !tar zcvf ../mifgsm.tgz *
# %cd ..
# Out:
# /mifgsm
# airplane/
# airplane/airplane9.png
# airplane/airplane16.png
# airplane/airplane2.png
# airplane/airplane14.png
# airplane/airplane19.png
# airplane/airplane8.png
# airplane/airplane10.png
# airplane/airplane15.png
# airplane/airplane17.png
# airplane/airplane3.png
# airplane/airplane6.png
# airplane/airplane4.png
# airplane/airplane20.png
# airplane/airplane7.png
# airplane/airplane13.png
# airplane/airplane1.png
# airplane/airplane18.png
# airplane/airplane5.png
# airplane/airplane11.png
# airplane/airplane12.png
# automobile/
# automobile/automobile5.png
# automobile/automobile6.png
# automobile/automobile17.png
# automobile/automobile9.png
# automobile/automobile11.png
# automobile/automobile19.png
# automobile/automobile4.png
# automobile/automobile14.png
# automobile/automobile2.png
# automobile/automobile20.png
# automobile/automobile7.png
# automobile/automobile13.png
# automobile/automobile12.png
# automobile/automobile8.png
# automobile/automobile1.png
# automobile/automobile15.png
# automobile/automobile18.png
# automobile/automobile3.png
# automobile/automobile10.png
# automobile/automobile16.png
# bird/
# bird/bird4.png
# bird/bird6.png
# bird/bird15.png
# bird/bird8.png
# bird/bird13.png
# bird/bird1.png
# bird/bird10.png
# bird/bird19.png
# bird/bird14.png
# bird/bird3.png
# bird/bird20.png
# bird/bird16.png
# bird/bird2.png
# bird/bird5.png
# bird/bird12.png
# bird/bird18.png
# bird/bird7.png
# bird/bird11.png
# bird/bird17.png
# bird/bird9.png
# cat/
# cat/cat14.png
# cat/cat9.png
# cat/cat12.png
# cat/cat7.png
# cat/cat6.png
# cat/cat8.png
# cat/cat5.png
# cat/cat20.png
# cat/cat10.png
# cat/cat19.png
# cat/cat3.png
# cat/cat13.png
# cat/cat15.png
# cat/cat16.png
# cat/cat2.png
# cat/cat11.png
# cat/cat4.png
# cat/cat1.png
# cat/cat17.png
# cat/cat18.png
# deer/
# deer/deer11.png
# deer/deer15.png
# deer/deer2.png
# deer/deer17.png
# deer/deer13.png
# deer/deer14.png
# deer/deer12.png
# deer/deer9.png
# deer/deer6.png
# deer/deer7.png
# deer/deer8.png
# deer/deer10.png
# deer/deer20.png
# deer/deer5.png
# deer/deer16.png
# deer/deer3.png
# deer/deer19.png
# deer/deer18.png
# deer/deer4.png
# deer/deer1.png
# dog/
# dog/dog4.png
# dog/dog17.png
# dog/dog9.png
# dog/dog18.png
# dog/dog20.png
# dog/dog8.png
# dog/dog19.png
# dog/dog15.png
# dog/dog5.png
# dog/dog14.png
# dog/dog11.png
# dog/dog10.png
# dog/dog12.png
# dog/dog16.png
# dog/dog7.png
# dog/dog2.png
# dog/dog1.png
# dog/dog13.png
# dog/dog3.png
# dog/dog6.png
# frog/
# frog/frog6.png
# frog/frog4.png
# frog/frog3.png
# frog/frog13.png
# frog/frog1.png
# frog/frog8.png
# frog/frog16.png
# frog/frog14.png
# frog/frog17.png
# frog/frog7.png
# frog/frog5.png
# frog/frog18.png
# frog/frog19.png
# frog/frog15.png
# frog/frog9.png
# frog/frog20.png
# frog/frog11.png
# frog/frog10.png
# frog/frog12.png
# frog/frog2.png
# horse/
# horse/horse7.png
# horse/horse15.png
# horse/horse17.png
# horse/horse20.png
# horse/horse13.png
# horse/horse8.png
# horse/horse11.png
# horse/horse19.png
# horse/horse6.png
# horse/horse18.png
# horse/horse4.png
# horse/horse1.png
# horse/horse10.png
# horse/horse14.png
# horse/horse3.png
# horse/horse12.png
# horse/horse16.png
# horse/horse9.png
# horse/horse5.png
# horse/horse2.png
# ship/
# ship/ship6.png
# ship/ship3.png
# ship/ship20.png
# ship/ship10.png
# ship/ship17.png
# ship/ship16.png
# ship/ship19.png
# ship/ship18.png
# ship/ship14.png
# ship/ship2.png
# ship/ship1.png
# ship/ship13.png
# ship/ship12.png
# ship/ship4.png
# ship/ship8.png
# ship/ship15.png
# ship/ship11.png
# ship/ship9.png
# ship/ship5.png
# ship/ship7.png
# truck/
# truck/truck7.png
# truck/truck2.png
# truck/truck13.png
# truck/truck14.png
# truck/truck6.png
# truck/truck4.png
# truck/truck12.png
# truck/truck10.png
# truck/truck15.png
# truck/truck19.png
# truck/truck8.png
# truck/truck11.png
# truck/truck1.png
# truck/truck17.png
# truck/truck20.png
# truck/truck16.png
# truck/truck5.png
# truck/truck18.png
# truck/truck9.png
# truck/truck3.png
# /

# %% [markdown]
# ## Visualization

# %%
import matplotlib.pyplot as plt

classes = ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

plt.figure(figsize=(10, 20))
cnt = 0
for i, cls_name in enumerate(classes):
    path = f'{cls_name}/{cls_name}1.png'
    # benign image
    cnt += 1
    plt.subplot(len(classes), 4, cnt)
    im = Image.open(f'./data/{path}')
    logit = model(transform(im).unsqueeze(0).to(device))[0]
    predict = logit.argmax(-1).item()
    prob = logit.softmax(-1)[predict].item()
    plt.title(f'benign: {cls_name}1.png\n{classes[predict]}: {prob:.2%}')
    plt.axis('off')
    plt.imshow(np.array(im))
    # adversarial image
    cnt += 1
    plt.subplot(len(classes), 4, cnt)
    im = Image.open(f'./fgsm/{path}')
    logit = model(transform(im).unsqueeze(0).to(device))[0]
    predict = logit.argmax(-1).item()
    prob = logit.softmax(-1)[predict].item()
    plt.title(f'adversarial: {cls_name}1.png\n{classes[predict]}: {prob:.2%}')
    plt.axis('off')
    plt.imshow(np.array(im))
plt.tight_layout()
plt.show()
